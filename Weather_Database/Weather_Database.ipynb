# %% [markdown]
# ## Deliverable 1. Retrieve Weather Data

# %%
# Import the dependencies.

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from config import g_key
from datetime import datetime

# %%
# 3. Create a new set of 2,000 random latitudes and longitudes 

lats = np.random.uniform(-90.000, 90.000, size = 2000)
lngs = np.random.uniform(-180.000, 180.000, size = 2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# 4. Get the nearest city using the citipy module.

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 730

# %%
# 5. Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# 6. Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_country = city_weather["sys"]["country"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather['weather'][0]['description']
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | saint-augustin
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | soyo
# Processing Record 5 of Set 1 | provideniya
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | iqaluit
# Processing Record 8 of Set 1 | fayaoue
# Processing Record 9 of Set 1 | ponta do sol
# Processing Record 10 of Set 1 | upernavik
# Processing Record 11 of Set 1 | jinchang
# Processing Record 12 of Set 1 | lucapa
# Processing Record 13 of Set 1 | port lincoln
# Processing Record 14 of Set 1 | ust-nera
# Processing Record 15 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | dikson
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | geraldton
# Processing Record 22 of Set 1 | vagay
# Processing Record 23 of Set 1 | cherskiy
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | isangel
# Processing Record 27 of Set 1 | pacific grove
# Processing Record 28 of Set 1 | torbay
# Processing Record 29 of Set 1 | norman wells
# Processing Record 30 of Set 1 | mahebourg
# Processing Record 31 of Set 1 | caravelas
# Processing Record 32 of Set 1 | vostok
# Processing Record 33 of Set 1 | hasaki
# Processing Record 34 of Set 1 | shizunai
# Processing Record 35 of Set 1 | port elizabeth
# Processing Record 36 of Set 1 | namibe
# Processing Record 37 of Set 1 | aklavik
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | saskylakh
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | kodiak
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | tual
# Processing Record 44 of Set 1 | keelung
# Processing Record 45 of Set 1 | haukipudas
# Processing Record 46 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 1 | flinders
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | naftah
# City not found. Skipping...
# Processing Record 50 of Set 1 | salalah
# Processing Record 1 of Set 2 | kamina
# Processing Record 2 of Set 2 | sabang
# Processing Record 3 of Set 2 | lavrentiya
# Processing Record 4 of Set 2 | lebu
# Processing Record 5 of Set 2 | longyearbyen
# Processing Record 6 of Set 2 | hambantota
# Processing Record 7 of Set 2 | yumen
# Processing Record 8 of Set 2 | katsuura
# Processing Record 9 of Set 2 | zyryanka
# Processing Record 10 of Set 2 | caceres
# Processing Record 11 of Set 2 | kapustin yar
# Processing Record 12 of Set 2 | punta arenas
# Processing Record 13 of Set 2 | bubaque
# Processing Record 14 of Set 2 | severo-kurilsk
# Processing Record 15 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 2 | bengkulu
# Processing Record 17 of Set 2 | husavik
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 2 | poso
# Processing Record 21 of Set 2 | barrow
# Processing Record 22 of Set 2 | rikitea
# Processing Record 23 of Set 2 | kathmandu
# Processing Record 24 of Set 2 | gaya
# Processing Record 25 of Set 2 | iguape
# Processing Record 26 of Set 2 | apricena
# Processing Record 27 of Set 2 | eslov
# Processing Record 28 of Set 2 | victoria
# Processing Record 29 of Set 2 | pemangkat
# Processing Record 30 of Set 2 | yeletskiy
# City not found. Skipping...
# Processing Record 31 of Set 2 | chapleau
# Processing Record 32 of Set 2 | khatanga
# Processing Record 33 of Set 2 | faya
# Processing Record 34 of Set 2 | avarua
# Processing Record 35 of Set 2 | sayyan
# Processing Record 36 of Set 2 | carnarvon
# Processing Record 37 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 2 | henties bay
# Processing Record 39 of Set 2 | bashtanka
# Processing Record 40 of Set 2 | new norfolk
# Processing Record 41 of Set 2 | kamalpur
# Processing Record 42 of Set 2 | dudinka
# Processing Record 43 of Set 2 | prince rupert
# Processing Record 44 of Set 2 | gravelbourg
# Processing Record 45 of Set 2 | cockburn town
# Processing Record 46 of Set 2 | port blair
# Processing Record 47 of Set 2 | miri
# Processing Record 48 of Set 2 | puerto ayora
# Processing Record 49 of Set 2 | hamilton
# Processing Record 50 of Set 2 | san patricio
# Processing Record 1 of Set 3 | pevek
# Processing Record 2 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 3 | portland
# Processing Record 4 of Set 3 | clyde river
# Processing Record 5 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 3 | ziyang
# Processing Record 7 of Set 3 | puerto rondon
# Processing Record 8 of Set 3 | jambi
# Processing Record 9 of Set 3 | codrington
# Processing Record 10 of Set 3 | bathsheba
# Processing Record 11 of Set 3 | tiksi
# Processing Record 12 of Set 3 | victor harbor
# Processing Record 13 of Set 3 | pousat
# City not found. Skipping...
# Processing Record 14 of Set 3 | chokurdakh
# Processing Record 15 of Set 3 | cabo san lucas
# Processing Record 16 of Set 3 | aquiraz
# Processing Record 17 of Set 3 | constitucion
# Processing Record 18 of Set 3 | kapaa
# Processing Record 19 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 3 | hobart
# Processing Record 21 of Set 3 | korla
# Processing Record 22 of Set 3 | aksarka
# Processing Record 23 of Set 3 | thompson
# Processing Record 24 of Set 3 | namatanai
# Processing Record 25 of Set 3 | pimentel
# Processing Record 26 of Set 3 | pianco
# Processing Record 27 of Set 3 | ithaca
# Processing Record 28 of Set 3 | vao
# Processing Record 29 of Set 3 | port alfred
# Processing Record 30 of Set 3 | diamantino
# Processing Record 31 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 3 | bluff
# Processing Record 33 of Set 3 | antalaha
# Processing Record 34 of Set 3 | nanortalik
# Processing Record 35 of Set 3 | kailua
# Processing Record 36 of Set 3 | alexandria
# Processing Record 37 of Set 3 | shivrajpur
# Processing Record 38 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 3 | muros
# Processing Record 40 of Set 3 | uray
# Processing Record 41 of Set 3 | taua
# Processing Record 42 of Set 3 | hilo
# Processing Record 43 of Set 3 | bonavista
# Processing Record 44 of Set 3 | doha
# Processing Record 45 of Set 3 | arraial do cabo
# Processing Record 46 of Set 3 | chapais
# Processing Record 47 of Set 3 | bochnia
# Processing Record 48 of Set 3 | ewo
# Processing Record 49 of Set 3 | karratha
# Processing Record 50 of Set 3 | kabalo
# Processing Record 1 of Set 4 | hualmay
# Processing Record 2 of Set 4 | bethel
# Processing Record 3 of Set 4 | darab
# Processing Record 4 of Set 4 | esperance
# Processing Record 5 of Set 4 | qasigiannguit
# Processing Record 6 of Set 4 | bambous virieux
# Processing Record 7 of Set 4 | rawson
# Processing Record 8 of Set 4 | ziro
# Processing Record 9 of Set 4 | kortkeros
# Processing Record 10 of Set 4 | itaituba
# Processing Record 11 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 4 | cayenne
# Processing Record 13 of Set 4 | svetlyy
# Processing Record 14 of Set 4 | namikupa
# Processing Record 15 of Set 4 | kushiro
# Processing Record 16 of Set 4 | dingle
# Processing Record 17 of Set 4 | chuy
# Processing Record 18 of Set 4 | vila
# Processing Record 19 of Set 4 | castro
# Processing Record 20 of Set 4 | lasa
# Processing Record 21 of Set 4 | cutro
# Processing Record 22 of Set 4 | houma
# Processing Record 23 of Set 4 | bijie
# Processing Record 24 of Set 4 | issia
# Processing Record 25 of Set 4 | pisco
# Processing Record 26 of Set 4 | abrau-dyurso
# Processing Record 27 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 28 of Set 4 | east london
# Processing Record 29 of Set 4 | little current
# Processing Record 30 of Set 4 | ribeira grande
# Processing Record 31 of Set 4 | te anau
# Processing Record 32 of Set 4 | samarai
# Processing Record 33 of Set 4 | haradok
# Processing Record 34 of Set 4 | male
# Processing Record 35 of Set 4 | college
# Processing Record 36 of Set 4 | anadyr
# Processing Record 37 of Set 4 | ridgecrest
# Processing Record 38 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 4 | fortuna
# Processing Record 40 of Set 4 | hithadhoo
# Processing Record 41 of Set 4 | nizhniy kuranakh
# Processing Record 42 of Set 4 | richards bay
# Processing Record 43 of Set 4 | kon tum
# Processing Record 44 of Set 4 | eatonton
# Processing Record 45 of Set 4 | zhicheng
# Processing Record 46 of Set 4 | dhali
# Processing Record 47 of Set 4 | tilichiki
# Processing Record 48 of Set 4 | lodja
# Processing Record 49 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 4 | mabaruma
# Processing Record 1 of Set 5 | srednekolymsk
# Processing Record 2 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 5 | san juan
# Processing Record 4 of Set 5 | bilma
# Processing Record 5 of Set 5 | tamalin
# Processing Record 6 of Set 5 | burica
# City not found. Skipping...
# Processing Record 7 of Set 5 | les cayes
# Processing Record 8 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 5 | lusambo
# Processing Record 10 of Set 5 | havelock
# Processing Record 11 of Set 5 | kruisfontein
# Processing Record 12 of Set 5 | conde
# Processing Record 13 of Set 5 | gamboma
# Processing Record 14 of Set 5 | buxar
# Processing Record 15 of Set 5 | bodden town
# Processing Record 16 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 5 | la ronge
# Processing Record 18 of Set 5 | georgetown
# Processing Record 19 of Set 5 | coquimbo
# Processing Record 20 of Set 5 | shache
# Processing Record 21 of Set 5 | puerto lumbreras
# Processing Record 22 of Set 5 | laconia
# Processing Record 23 of Set 5 | yamada
# Processing Record 24 of Set 5 | storsteinnes
# Processing Record 25 of Set 5 | general higinio morinigo
# Processing Record 26 of Set 5 | mar del plata
# Processing Record 27 of Set 5 | kirakira
# Processing Record 28 of Set 5 | ancud
# Processing Record 29 of Set 5 | ahipara
# Processing Record 30 of Set 5 | saint anthony
# Processing Record 31 of Set 5 | swindon
# Processing Record 32 of Set 5 | okhotsk
# Processing Record 33 of Set 5 | hendijan
# City not found. Skipping...
# Processing Record 34 of Set 5 | morondava
# Processing Record 35 of Set 5 | umm lajj
# Processing Record 36 of Set 5 | bandarbeyla
# Processing Record 37 of Set 5 | presidente medici
# Processing Record 38 of Set 5 | champerico
# Processing Record 39 of Set 5 | davila
# Processing Record 40 of Set 5 | grayslake
# Processing Record 41 of Set 5 | rocha
# Processing Record 42 of Set 5 | la reforma
# Processing Record 43 of Set 5 | luderitz
# Processing Record 44 of Set 5 | pangnirtung
# Processing Record 45 of Set 5 | qandahar
# City not found. Skipping...
# Processing Record 46 of Set 5 | gazanjyk
# Processing Record 47 of Set 5 | kawana waters
# City not found. Skipping...
# Processing Record 48 of Set 5 | naryan-mar
# Processing Record 49 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 5 | fairbanks
# Processing Record 1 of Set 6 | inhambane
# Processing Record 2 of Set 6 | novomyshastovskaya
# Processing Record 3 of Set 6 | banjar
# Processing Record 4 of Set 6 | san cristobal
# Processing Record 5 of Set 6 | isla vista
# Processing Record 6 of Set 6 | kaitangata
# Processing Record 7 of Set 6 | beringovskiy
# Processing Record 8 of Set 6 | shanhetun
# Processing Record 9 of Set 6 | klaksvik
# Processing Record 10 of Set 6 | koygorodok
# Processing Record 11 of Set 6 | gazojak
# Processing Record 12 of Set 6 | ostrovnoy
# Processing Record 13 of Set 6 | fort nelson
# Processing Record 14 of Set 6 | devarkonda
# Processing Record 15 of Set 6 | laguna
# Processing Record 16 of Set 6 | shimoda
# Processing Record 17 of Set 6 | guerrero negro
# Processing Record 18 of Set 6 | santa isabel
# Processing Record 19 of Set 6 | rawatbhata
# Processing Record 20 of Set 6 | haines junction
# Processing Record 21 of Set 6 | abu samrah
# Processing Record 22 of Set 6 | sao joao da barra
# Processing Record 23 of Set 6 | weiser
# Processing Record 24 of Set 6 | margate
# Processing Record 25 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 6 | shenxian
# Processing Record 27 of Set 6 | lorengau
# Processing Record 28 of Set 6 | oussouye
# Processing Record 29 of Set 6 | grindavik
# Processing Record 30 of Set 6 | santa cruz cabralia
# Processing Record 31 of Set 6 | fort dodge
# Processing Record 32 of Set 6 | itupiranga
# Processing Record 33 of Set 6 | araouane
# Processing Record 34 of Set 6 | san isidro
# Processing Record 35 of Set 6 | krasnoborsk
# Processing Record 36 of Set 6 | fengzhen
# Processing Record 37 of Set 6 | coronel oviedo
# Processing Record 38 of Set 6 | chumikan
# Processing Record 39 of Set 6 | zhigansk
# Processing Record 40 of Set 6 | homer
# Processing Record 41 of Set 6 | nouadhibou
# Processing Record 42 of Set 6 | atambua
# Processing Record 43 of Set 6 | sao felix do xingu
# Processing Record 44 of Set 6 | lagoa
# Processing Record 45 of Set 6 | port hawkesbury
# Processing Record 46 of Set 6 | menongue
# Processing Record 47 of Set 6 | chissamba
# Processing Record 48 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 6 | cuamba
# Processing Record 50 of Set 6 | buraydah
# Processing Record 1 of Set 7 | lamballe
# Processing Record 2 of Set 7 | leo
# Processing Record 3 of Set 7 | whyalla
# Processing Record 4 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 5 of Set 7 | lata
# Processing Record 6 of Set 7 | vorukh
# Processing Record 7 of Set 7 | puerto escondido
# Processing Record 8 of Set 7 | butaritari
# Processing Record 9 of Set 7 | leningradskiy
# Processing Record 10 of Set 7 | manyana
# Processing Record 11 of Set 7 | erenhot
# Processing Record 12 of Set 7 | gao
# Processing Record 13 of Set 7 | camacha
# Processing Record 14 of Set 7 | yulara
# Processing Record 15 of Set 7 | gat
# Processing Record 16 of Set 7 | alihe
# Processing Record 17 of Set 7 | abapo
# Processing Record 18 of Set 7 | mbuguni
# Processing Record 19 of Set 7 | santa vitoria do palmar
# Processing Record 20 of Set 7 | buchanan
# Processing Record 21 of Set 7 | carlos chagas
# Processing Record 22 of Set 7 | caibarien
# Processing Record 23 of Set 7 | belfast
# Processing Record 24 of Set 7 | touros
# Processing Record 25 of Set 7 | ventspils
# Processing Record 26 of Set 7 | kahului
# Processing Record 27 of Set 7 | hami
# Processing Record 28 of Set 7 | kattivakkam
# Processing Record 29 of Set 7 | oranjestad
# Processing Record 30 of Set 7 | damara
# Processing Record 31 of Set 7 | el salto
# Processing Record 32 of Set 7 | saldanha
# Processing Record 33 of Set 7 | sun valley
# Processing Record 34 of Set 7 | nikolskoye
# Processing Record 35 of Set 7 | lagos
# Processing Record 36 of Set 7 | tateyama
# Processing Record 37 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 7 | simdega
# Processing Record 39 of Set 7 | mount gambier
# Processing Record 40 of Set 7 | auki
# Processing Record 41 of Set 7 | comodoro rivadavia
# Processing Record 42 of Set 7 | xochitlan
# Processing Record 43 of Set 7 | hobyo
# Processing Record 44 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 7 | yanam
# Processing Record 46 of Set 7 | atasu
# Processing Record 47 of Set 7 | shubarshi
# Processing Record 48 of Set 7 | moose factory
# Processing Record 49 of Set 7 | san andres
# Processing Record 50 of Set 7 | chicama
# Processing Record 1 of Set 8 | iquitos
# Processing Record 2 of Set 8 | alofi
# Processing Record 3 of Set 8 | imbituba
# Processing Record 4 of Set 8 | jumla
# Processing Record 5 of Set 8 | goure
# Processing Record 6 of Set 8 | souillac
# Processing Record 7 of Set 8 | djang
# City not found. Skipping...
# Processing Record 8 of Set 8 | wanning
# Processing Record 9 of Set 8 | lompoc
# Processing Record 10 of Set 8 | effingham
# Processing Record 11 of Set 8 | hofn
# Processing Record 12 of Set 8 | mount isa
# Processing Record 13 of Set 8 | mazagao
# Processing Record 14 of Set 8 | coihaique
# Processing Record 15 of Set 8 | wethersfield
# Processing Record 16 of Set 8 | nurota
# Processing Record 17 of Set 8 | sakakah
# Processing Record 18 of Set 8 | roma
# Processing Record 19 of Set 8 | khor
# Processing Record 20 of Set 8 | constantine
# Processing Record 21 of Set 8 | kavieng
# Processing Record 22 of Set 8 | darnah
# Processing Record 23 of Set 8 | ayacucho
# Processing Record 24 of Set 8 | rincon
# Processing Record 25 of Set 8 | cidreira
# Processing Record 26 of Set 8 | vardo
# Processing Record 27 of Set 8 | novaya zaimka
# Processing Record 28 of Set 8 | mildura
# Processing Record 29 of Set 8 | saint george
# Processing Record 30 of Set 8 | dharchula
# Processing Record 31 of Set 8 | maldonado
# Processing Record 32 of Set 8 | gobabis
# Processing Record 33 of Set 8 | sur
# Processing Record 34 of Set 8 | nome
# Processing Record 35 of Set 8 | yenagoa
# Processing Record 36 of Set 8 | shitanjing
# Processing Record 37 of Set 8 | yingcheng
# Processing Record 38 of Set 8 | north battleford
# Processing Record 39 of Set 8 | tiznit
# Processing Record 40 of Set 8 | urubicha
# Processing Record 41 of Set 8 | mirandela
# Processing Record 42 of Set 8 | sungaipenuh
# Processing Record 43 of Set 8 | airai
# Processing Record 44 of Set 8 | meadow lake
# Processing Record 45 of Set 8 | severobaykalsk
# Processing Record 46 of Set 8 | katherine
# Processing Record 47 of Set 8 | wattegama
# Processing Record 48 of Set 8 | garowe
# Processing Record 49 of Set 8 | baft
# Processing Record 50 of Set 8 | colares
# Processing Record 1 of Set 9 | mitsamiouli
# Processing Record 2 of Set 9 | langham
# Processing Record 3 of Set 9 | san carlos del zulia
# Processing Record 4 of Set 9 | tasiilaq
# Processing Record 5 of Set 9 | agadir
# Processing Record 6 of Set 9 | bure
# Processing Record 7 of Set 9 | axim
# Processing Record 8 of Set 9 | faanui
# Processing Record 9 of Set 9 | sola
# Processing Record 10 of Set 9 | cepu
# Processing Record 11 of Set 9 | vytegra
# Processing Record 12 of Set 9 | manggar
# Processing Record 13 of Set 9 | kankaanpaa
# Processing Record 14 of Set 9 | praya
# Processing Record 15 of Set 9 | redding
# Processing Record 16 of Set 9 | youhao
# Processing Record 17 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 18 of Set 9 | los llanos de aridane
# Processing Record 19 of Set 9 | cruzeiro do sul
# Processing Record 20 of Set 9 | ust-karsk
# Processing Record 21 of Set 9 | pemberton
# Processing Record 22 of Set 9 | sagua la grande
# Processing Record 23 of Set 9 | seoul
# Processing Record 24 of Set 9 | paamiut
# Processing Record 25 of Set 9 | halifax
# Processing Record 26 of Set 9 | mackay
# Processing Record 27 of Set 9 | khandyga
# Processing Record 28 of Set 9 | zabid
# Processing Record 29 of Set 9 | khomeyn
# Processing Record 30 of Set 9 | vila franca do campo
# Processing Record 31 of Set 9 | ambon
# Processing Record 32 of Set 9 | jacareacanga
# Processing Record 33 of Set 9 | kamskiye polyany
# Processing Record 34 of Set 9 | nara
# Processing Record 35 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 36 of Set 9 | tefe
# Processing Record 37 of Set 9 | petropavlovka
# Processing Record 38 of Set 9 | sorland
# Processing Record 39 of Set 9 | katangli
# Processing Record 40 of Set 9 | san jose
# Processing Record 41 of Set 9 | la rioja
# Processing Record 42 of Set 9 | maningrida
# Processing Record 43 of Set 9 | mazyr
# Processing Record 44 of Set 9 | meulaboh
# Processing Record 45 of Set 9 | tahta
# Processing Record 46 of Set 9 | asyut
# Processing Record 47 of Set 9 | zaltan
# Processing Record 48 of Set 9 | traverse city
# Processing Record 49 of Set 9 | great yarmouth
# Processing Record 50 of Set 9 | jalu
# Processing Record 1 of Set 10 | luancheng
# Processing Record 2 of Set 10 | santa cruz de tenerife
# Processing Record 3 of Set 10 | narsaq
# Processing Record 4 of Set 10 | dunedin
# Processing Record 5 of Set 10 | westport
# Processing Record 6 of Set 10 | charters towers
# Processing Record 7 of Set 10 | jieshou
# Processing Record 8 of Set 10 | louis trichardt
# Processing Record 9 of Set 10 | mayo
# Processing Record 10 of Set 10 | rundu
# Processing Record 11 of Set 10 | ilulissat
# Processing Record 12 of Set 10 | bulgan
# Processing Record 13 of Set 10 | shu
# Processing Record 14 of Set 10 | christchurch
# Processing Record 15 of Set 10 | puerto cortes
# City not found. Skipping...
# Processing Record 16 of Set 10 | bidar
# Processing Record 17 of Set 10 | vyazemskiy
# Processing Record 18 of Set 10 | tawau
# Processing Record 19 of Set 10 | nueva loja
# Processing Record 20 of Set 10 | santa rosalia
# Processing Record 21 of Set 10 | ketchikan
# Processing Record 22 of Set 10 | naliya
# Processing Record 23 of Set 10 | la macarena
# Processing Record 24 of Set 10 | atbasar
# Processing Record 25 of Set 10 | kiunga
# Processing Record 26 of Set 10 | uglovka
# Processing Record 27 of Set 10 | aswan
# Processing Record 28 of Set 10 | bambanglipuro
# Processing Record 29 of Set 10 | bayevo
# Processing Record 30 of Set 10 | taoudenni
# Processing Record 31 of Set 10 | gallup
# Processing Record 32 of Set 10 | aitape
# Processing Record 33 of Set 10 | marienburg
# Processing Record 34 of Set 10 | montlucon
# Processing Record 35 of Set 10 | nauta
# Processing Record 36 of Set 10 | russkaya polyana
# Processing Record 37 of Set 10 | asau
# Processing Record 38 of Set 10 | ipixuna
# Processing Record 39 of Set 10 | kedrovyy
# Processing Record 40 of Set 10 | juruti
# Processing Record 41 of Set 10 | nawa
# Processing Record 42 of Set 10 | yunhe
# Processing Record 43 of Set 10 | pimenta bueno
# Processing Record 44 of Set 10 | chekhov
# Processing Record 45 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 46 of Set 10 | port macquarie
# Processing Record 47 of Set 10 | altamira
# Processing Record 48 of Set 10 | san pedro
# Processing Record 49 of Set 10 | santa cruz
# Processing Record 50 of Set 10 | nadvoitsy
# Processing Record 1 of Set 11 | iroquois falls
# Processing Record 2 of Set 11 | sinop
# Processing Record 3 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 4 of Set 11 | parscov
# Processing Record 5 of Set 11 | tanjung morawa
# City not found. Skipping...
# Processing Record 6 of Set 11 | sokoto
# Processing Record 7 of Set 11 | el alto
# Processing Record 8 of Set 11 | hun
# Processing Record 9 of Set 11 | kalmunai
# Processing Record 10 of Set 11 | umm kaddadah
# Processing Record 11 of Set 11 | guozhen
# Processing Record 12 of Set 11 | forbes
# Processing Record 13 of Set 11 | nicolas bravo
# Processing Record 14 of Set 11 | kieta
# Processing Record 15 of Set 11 | vila velha
# Processing Record 16 of Set 11 | abonnema
# Processing Record 17 of Set 11 | kalabo
# Processing Record 18 of Set 11 | bababe
# City not found. Skipping...
# Processing Record 19 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 11 | luba
# Processing Record 21 of Set 11 | zeya
# Processing Record 22 of Set 11 | sungairaya
# Processing Record 23 of Set 11 | paidha
# Processing Record 24 of Set 11 | angoche
# Processing Record 25 of Set 11 | arrecife
# Processing Record 26 of Set 11 | uyuni
# Processing Record 27 of Set 11 | muravlenko
# Processing Record 28 of Set 11 | sonoita
# Processing Record 29 of Set 11 | alma
# Processing Record 30 of Set 11 | kashi
# Processing Record 31 of Set 11 | bjornevatn
# Processing Record 32 of Set 11 | betare oya
# Processing Record 33 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 34 of Set 11 | limoges
# Processing Record 35 of Set 11 | kolpashevo
# Processing Record 36 of Set 11 | bud
# Processing Record 37 of Set 11 | torata
# Processing Record 38 of Set 11 | talnakh
# Processing Record 39 of Set 11 | bokhan
# Processing Record 40 of Set 11 | ibra
# Processing Record 41 of Set 11 | monterey
# Processing Record 42 of Set 11 | deputatskiy
# Processing Record 43 of Set 11 | portpatrick
# City not found. Skipping...
# Processing Record 44 of Set 11 | kaeo
# Processing Record 45 of Set 11 | eydhafushi
# Processing Record 46 of Set 11 | grand-santi
# Processing Record 47 of Set 11 | kloulklubed
# Processing Record 48 of Set 11 | shingu
# Processing Record 49 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 50 of Set 11 | el carmen de bolivar
# Processing Record 1 of Set 12 | egvekinot
# Processing Record 2 of Set 12 | vitim
# Processing Record 3 of Set 12 | huarmey
# Processing Record 4 of Set 12 | bongor
# Processing Record 5 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 12 | biltine
# Processing Record 7 of Set 12 | dakar
# Processing Record 8 of Set 12 | ust-ilimsk
# Processing Record 9 of Set 12 | tsabong
# Processing Record 10 of Set 12 | pospelikha
# Processing Record 11 of Set 12 | myitkyina
# Processing Record 12 of Set 12 | huescar
# Processing Record 13 of Set 12 | litoral del san juan
# City not found. Skipping...
# Processing Record 14 of Set 12 | mandalgovi
# Processing Record 15 of Set 12 | porto novo
# Processing Record 16 of Set 12 | russell
# Processing Record 17 of Set 12 | svetlogorsk
# Processing Record 18 of Set 12 | brae
# Processing Record 19 of Set 12 | barra do garcas
# Processing Record 20 of Set 12 | jutiapa
# Processing Record 21 of Set 12 | charyshskoye
# Processing Record 22 of Set 12 | sardarpur
# Processing Record 23 of Set 12 | jingdezhen
# Processing Record 24 of Set 12 | mysliborz
# Processing Record 25 of Set 12 | sept-iles
# Processing Record 26 of Set 12 | capoeiras
# Processing Record 27 of Set 12 | clonmel
# Processing Record 28 of Set 12 | nhulunbuy
# Processing Record 29 of Set 12 | rocky mountain house
# Processing Record 30 of Set 12 | svetlaya
# Processing Record 31 of Set 12 | kisangani
# Processing Record 32 of Set 12 | san felipe
# Processing Record 33 of Set 12 | dungarpur
# Processing Record 34 of Set 12 | teknaf
# Processing Record 35 of Set 12 | chukhloma
# Processing Record 36 of Set 12 | sechura
# Processing Record 37 of Set 12 | san lorenzo
# Processing Record 38 of Set 12 | bonthe
# Processing Record 39 of Set 12 | labytnangi
# Processing Record 40 of Set 12 | bonito
# Processing Record 41 of Set 12 | yemtsa
# Processing Record 42 of Set 12 | longyan
# Processing Record 43 of Set 12 | pishin
# Processing Record 44 of Set 12 | kota belud
# Processing Record 45 of Set 12 | kamenka
# Processing Record 46 of Set 12 | gua musang
# Processing Record 47 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 48 of Set 12 | chiang khong
# Processing Record 49 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 12 | buala
# Processing Record 1 of Set 13 | tunduru
# City not found. Skipping...
# Processing Record 2 of Set 13 | carauari
# Processing Record 3 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 4 of Set 13 | kununurra
# Processing Record 5 of Set 13 | khormuj
# City not found. Skipping...
# Processing Record 6 of Set 13 | rabo de peixe
# Processing Record 7 of Set 13 | atar
# Processing Record 8 of Set 13 | talara
# Processing Record 9 of Set 13 | sitka
# Processing Record 10 of Set 13 | riyadh
# Processing Record 11 of Set 13 | zapolyarnyy
# Processing Record 12 of Set 13 | ahuimanu
# Processing Record 13 of Set 13 | graham
# Processing Record 14 of Set 13 | elizabeth city
# Processing Record 15 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 16 of Set 13 | puerto carreno
# Processing Record 17 of Set 13 | san quintin
# Processing Record 18 of Set 13 | jhawarian
# Processing Record 19 of Set 13 | yazykovo
# Processing Record 20 of Set 13 | svobodnyy
# Processing Record 21 of Set 13 | matiguas
# Processing Record 22 of Set 13 | lakhnadon
# Processing Record 23 of Set 13 | kendari
# Processing Record 24 of Set 13 | zaragoza
# Processing Record 25 of Set 13 | broome
# Processing Record 26 of Set 13 | beloha
# Processing Record 27 of Set 13 | hopkinsville
# Processing Record 28 of Set 13 | chimbote
# Processing Record 29 of Set 13 | tocopilla
# Processing Record 30 of Set 13 | baherden
# Processing Record 31 of Set 13 | laureles
# Processing Record 32 of Set 13 | gollere
# City not found. Skipping...
# Processing Record 33 of Set 13 | otjiwarongo
# Processing Record 34 of Set 13 | bikin
# Processing Record 35 of Set 13 | koutsouras
# Processing Record 36 of Set 13 | mamallapuram
# Processing Record 37 of Set 13 | osa
# Processing Record 38 of Set 13 | havre-saint-pierre
# Processing Record 39 of Set 13 | cedar city
# Processing Record 40 of Set 13 | aliwal north
# Processing Record 41 of Set 13 | tawang
# Processing Record 42 of Set 13 | kadoma
# Processing Record 43 of Set 13 | domat
# Processing Record 44 of Set 13 | beyneu
# Processing Record 45 of Set 13 | nivala
# Processing Record 46 of Set 13 | astoria
# Processing Record 47 of Set 13 | timberlake
# Processing Record 48 of Set 13 | hermsdorf
# Processing Record 49 of Set 13 | nishihara
# Processing Record 50 of Set 13 | evensk
# Processing Record 1 of Set 14 | lar gerd
# City not found. Skipping...
# Processing Record 2 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 3 of Set 14 | taraz
# Processing Record 4 of Set 14 | jieshi
# Processing Record 5 of Set 14 | necochea
# Processing Record 6 of Set 14 | sampit
# Processing Record 7 of Set 14 | kirillov
# Processing Record 8 of Set 14 | orlik
# Processing Record 9 of Set 14 | san rafael
# Processing Record 10 of Set 14 | banda aceh
# Processing Record 11 of Set 14 | kysyl-syr
# Processing Record 12 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 13 of Set 14 | pictou
# Processing Record 14 of Set 14 | lethem
# Processing Record 15 of Set 14 | nipawin
# Processing Record 16 of Set 14 | dicabisagan
# Processing Record 17 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 14 | dalhousie
# Processing Record 19 of Set 14 | koungou
# Processing Record 20 of Set 14 | skjaerhollen
# City not found. Skipping...
# Processing Record 21 of Set 14 | wajir
# Processing Record 22 of Set 14 | michigan city
# Processing Record 23 of Set 14 | stekolnyy
# City not found. Skipping...
# Processing Record 24 of Set 14 | nizwa
# Processing Record 25 of Set 14 | miles city
# Processing Record 26 of Set 14 | campohermoso
# Processing Record 27 of Set 14 | cody
# Processing Record 28 of Set 14 | hvammstangi
# City not found. Skipping...
# Processing Record 29 of Set 14 | muscat
# Processing Record 30 of Set 14 | balikpapan
# Processing Record 31 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 32 of Set 14 | olinda
# Processing Record 33 of Set 14 | podporozhye
# Processing Record 34 of Set 14 | asosa
# Processing Record 35 of Set 14 | verkhnyaya toyma
# Processing Record 36 of Set 14 | muisne
# Processing Record 37 of Set 14 | bac lieu
# Processing Record 38 of Set 14 | bushenyi
# Processing Record 39 of Set 14 | bo rai
# Processing Record 40 of Set 14 | cururupu
# Processing Record 41 of Set 14 | port-gentil
# Processing Record 42 of Set 14 | vaitape
# Processing Record 43 of Set 14 | moron
# Processing Record 44 of Set 14 | sidi ali
# Processing Record 45 of Set 14 | macklin
# Processing Record 46 of Set 14 | komsomolskiy
# Processing Record 47 of Set 14 | poum
# Processing Record 48 of Set 14 | high rock
# Processing Record 49 of Set 14 | maputo
# Processing Record 50 of Set 14 | horsham
# Processing Record 1 of Set 15 | lerwick
# Processing Record 2 of Set 15 | taltal
# Processing Record 3 of Set 15 | corinto
# Processing Record 4 of Set 15 | tibati
# Processing Record 5 of Set 15 | magadan
# Processing Record 6 of Set 15 | bajil
# Processing Record 7 of Set 15 | avanigadda
# Processing Record 8 of Set 15 | namtsy
# Processing Record 9 of Set 15 | luang prabang
# Processing Record 10 of Set 15 | playa vicente
# Processing Record 11 of Set 15 | northam
# Processing Record 12 of Set 15 | mahina
# Processing Record 13 of Set 15 | shaunavon
# Processing Record 14 of Set 15 | srandakan
# Processing Record 15 of Set 15 | kargopol
# Processing Record 16 of Set 15 | znamenskoye
# Processing Record 17 of Set 15 | lastoursville
# Processing Record 18 of Set 15 | biak
# Processing Record 19 of Set 15 | verkh-usugli
# Processing Record 20 of Set 15 | calabozo
# Processing Record 21 of Set 15 | vaniyambadi
# Processing Record 22 of Set 15 | mudyuga
# City not found. Skipping...
# Processing Record 23 of Set 15 | padang
# Processing Record 24 of Set 15 | port hardy
# Processing Record 25 of Set 15 | belyy yar
# Processing Record 26 of Set 15 | santa isabel do rio negro
# Processing Record 27 of Set 15 | luganville
# Processing Record 28 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 15 | kavaratti
# Processing Record 30 of Set 15 | tazovskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 7. Add the data to a new DataFrame.
city_data_df= pd.DataFrame(city_data)
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ushuaia      AR -54.8000  -68.3000     55.40        67          20
# 1  Saint-Augustin      CA  51.2260  -58.6502     34.50        96          98
# 2       Jamestown      US  42.0970  -79.2353     35.60        48           1
# 3            Soyo      AO  -6.1349   12.3689     81.05        84         100
# 4     Provideniya      RU  64.3833 -173.3000     -9.94        87         100
#
#    Wind Speed Current Description
# 0       37.98          few clouds
# 1        3.38     overcast clouds
# 2        8.05           clear sky
# 3        8.75     overcast clouds
# 4       28.03          light snow

# %%
# 8.Export the DataFrame as a CSV file

# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
